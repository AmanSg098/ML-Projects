# %% [markdown]
# ### IPL 2024 Orange Cap Players Web Scraped Dataset

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# <font size=3>Parsing the url</font>

# %%
url = "https://www.iplt20.com/stats/2024"
response = requests.get(url)
# checking the website response
response        # ok
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text,"lxml")
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <title data-page-title="IPL 2024 Statistics | Team and Player Stats" id="page_title">IPL 2024 Statistics | Team and Player Stats</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, user-scalable=no" name="viewport"/>
# <meta content="k33uIiABmmeT5UYYeh0cqn6S5Yv19jBFKRjeNmaR" name="csrf-token"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <link href="https://www.iplt20.com/stats/2024" rel="canonical"/>
# <meta content="#19398a" name="theme-color"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="website" name="og:type"/>
# <meta content="IPL 2024 Statistics | Team and Player Stats" name="twitter:title"/>
# <meta content="https://www.iplt20.com/stats/2024" name="og:url"/>
# <meta content="IPL 2024 Statistics | Team and Player Stats" name="og:title"/>
# ...

# %%
div_table = soup.find("div", class_="np-battingtable_contaner  2024")
print(div_table)
# Out:
# None

# %%
div_table = soup.find("div",
                  class_ = "st-table-wrap tab-content scrollt",
                  id="battingTAB")
print(div_table)
# Out:
# None
